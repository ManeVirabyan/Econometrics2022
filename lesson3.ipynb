# %%
=if  elif elce

# %%
num = 100

# %%
if num == 100:
    print ('one hundred')
else:
    print ('This number is not one hundred')
# Out:
# one hundred

# %%
In = [1, 2, 3, 4, 10]

# %%
ls1 = ['toy', 'ball', 1, 3, 5, True]

# %%
if True in ls1:
    print('True is found in ls1')
else:
   print('True is not found')
# Out:
# True is found in ls1

# %%
if type(ls1[0] == str):
    print('There is a string in list')
elif type(ls[1] == int):
    print('There is an integar in list')
else:
    print('No connections found')
# Out:
# There is a string in list
